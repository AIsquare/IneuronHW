# %% [markdown]
# **In this assignment students have to transform iris data into 3 dimensions
# and plot a 3d chart with transformed dimensions and colour each data
# point with specific class.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
#from sklearn import datasets
import seaborn as sns
import pandas as pd

# %%
data = sns.load_dataset('iris')

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.drop('species',inplace=True,axis=1)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
xs = data['sepal_length']
xs.head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal_length, dtype: float64

# %%
ys = data['sepal_width']

# %%
zs = data['petal_length']

# %%
z1 = data['petal_width']

# %%
fig = plt.figure(figsize=(20,10))
ax = Axes3D(fig, elev=-170, azim=120)

ax.scatter(xs, ys, zs, zdir='z', cmap='virdis', edgecolor='b', s=40,linewidth=0.5)
ax.set_xlabel('Sepal_length')
ax.set_ylabel('Sepal_width')
ax.set_zlabel('Petal_lenght')
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
ax = Axes3D(fig, elev=-170, azim=120)

ax.scatter(xs, ys, z1, zdir='z', cmap='virdis', edgecolor='b', s=40,linewidth=0.5)
ax.set_xlabel('Sepal_length')
ax.set_ylabel('Sepal_width')
ax.set_zlabel('Petal_width')
plt.show()
